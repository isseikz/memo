# %% [markdown]
# <a href="https://colab.research.google.com/github/isseikz/memo/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pythonで行う画像分類
# ===

# %% [markdown]
# # 目次
# 1. データを集める
# 1. モデルを作る
# 1. データをモデルに学習させる
# 1. モデルを評価する
# 1. モデルで予測する

# %% [markdown]
# # 1. データを集める
#
# モデルを作るために必要なデータを集めます。

# %%
from google.colab import drive
drive.mount('./gdrive')
drive_root_dir="./gdrive/My Drive/MoonCraterDetection"

# %%
# スクレイピングの学習 Python3系 その2 (@mizssy07 2018年08月18日に投稿) を参考にした
# https://qiita.com/mizssy07/items/0f4ca2d7e6f9e022c5e2

import bs4
import requests
import re
import urllib.request, urllib.error
import shutil
import os
import argparse
import sys
import json

crater_name_list = [
      "Albategnius", "Aristarchus", "Aristotle", "Bailly", "Clavius",
      "Copernicus", "Humboldt", "Janssen", "Langrenus",
      "Longomontanus", "Maginus", "Metius", "Moretus", "Petavius", "Picard",
      "Piccolomini", "Pitatus", "Plinius", "Rheita", "Russell", "Schickard",
      "Seleucus", "Stadius", "Stöfler", "Thebit", "Theophilus", "Tycho",
      "Vendelinus", "Wargentin"
    ]

def get_soup(url,header):
    return bs4.BeautifulSoup(urllib.request.urlopen(urllib.request.Request(url,headers=header)),'html.parser')

def section1_main():
    
    
    for crater_name in crater_name_list:
      url="https://www.google.co.jp/search?q="+"moon+crater+"+crater_name+"&source=lnms&tbm=isch"
      header={'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.134 Safari/537.36"}
      soup = get_soup(url,header)
      ActualImages=[]

      save_directory = drive_root_dir + "/resources/" + crater_name
      if os.path.exists(save_directory):
        shutil.rmtree(save_directory)

      os.makedirs(save_directory)

      for a in soup.find_all("div",{"class":"rg_meta"}):
        link , Type =json.loads(a.text)["ou"]  ,json.loads(a.text)["ity"]
        ActualImages.append((link,Type))
      for i , (img , Type) in enumerate( ActualImages):
        try:
          Type = Type if len(Type) > 0 else 'jpg'
          print("Downloading image {} ({}), type is {}".format(i, img, Type))
          raw_img = urllib.request.urlopen(img).read()
          f = open(os.path.join(save_directory , "img_"+str(i)+"."+Type), 'wb')
          f.write(raw_img)
          f.close()
        except Exception as e:
          print ("could not load : "+img)
          print (e)

# %%
 section1_main()
# Out:
# Downloading image 0 (https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Albategnius_crater_4101_h2_h3.jpg/220px-Albategnius_crater_4101_h2_h3.jpg), type is jpg
# Downloading image 1 (https://upload.wikimedia.org/wikipedia/commons/thumb/4/43/Albategnius_lunar_crater_map.jpg/220px-Albategnius_lunar_crater_map.jpg), type is jpg
# Downloading image 2 (https://upload.wikimedia.org/wikipedia/commons/c/c5/Location_of_albategnius_crater.jpg), type is jpg
# Downloading image 3 (https://upload.wikimedia.org/wikipedia/commons/thumb/5/59/Albategnius_crater_AS16-M-2472.jpg/220px-Albategnius_crater_AS16-M-2472.jpg), type is jpg
# Downloading image 4 (http://andrewplanck.com/wp-content/uploads/2018/05/Albategnius-on-Moon.png), type is png
# could not load : http://andrewplanck.com/wp-content/uploads/2018/05/Albategnius-on-Moon.png
# HTTP Error 412: Precondition Failed
# Downloading image 5 (https://the-moon.us/images/d/d5/Normal_Albategnius040906_04-39-59.jpg), type is jpg
# Downloading image 6 (http://i1215.photobucket.com/albums/cc517/lupuvictor1/AlbategniusandHipparchusCraters.jpg), type is jpg
# Downloading image 7 (http://www.salzgeber.at/astro/moon/hipparchus_delambre.jpg), type is jpg
# Downloading image 8 (https://sites.google.com/site/mickhyde/albategnius-klein-281206.jpg), type is jpg
# Downloading image 9 (https://www.cloudynights.com/uploads/monthly_04_2018/post-263915-0-00601000-1522575420.jpg), type is jpg
# could not load : https://www.cloudynights.com/uploads/monthly_04_2018/post-263915-0-00601000-1522575420.jpg
# HTTP Error 403: Forbidden
# Downloading image 10 (https://upload.wikimedia.org/wikipedia/commons/9/98/Ptolemaeus_%2B_Alphonsus_%2B_Hipparchus_%2B_Albategnius_-_LROC_-_WAC.JPG), type is jpg
# Downloading image 11 (https://stargazerslounge.com/uploads/monthly_2018_01/5a640d35107cb_AlbategniuscraterIr685filter.png.74bba66564d71b2393993c775b8c27a6.png), type is png
# Downloading image 12 (http://www.salzgeber.at/astro/moon/hipparchus.jpg), type is jpg
# Downloading image 13 (https://farm6.static.flickr.com/5746/30903429285_707461823d_b.jpg), type is jpg
# Downloading image 14 (https://the-moon.us/images/c/c8/Albategnius.jpg), type is jpg
# Downloading image 15 (https://nssdc.gsfc.nasa.gov/imgcat/hires/ra9_b001.gif), type is gif
# Downloading image 16 (http://meteomauritius.altervista.org/gallerynew/cache/moon/moon_05062014_zwo-asi120mm_180841_uvircut_as_f1035_g6_ap135-ps_595.jpg), type is jpg
# Downloading image 17 (http://andrewplanck.com/wp-content/uploads/2018/05/Albategnius-85-mile-complex-crater.png), type is png
# could not load : http://andrewplanck.com/wp-content/uploads/2018/05/Albategnius-85-mile-complex-crater.png
# HTTP Error 412: Precondition Failed
# Downloading image 18 (http://i941.photobucket.com/albums/ad252/lupuvictor/AlbategniusHipparchus.jpg), type is jpg
# Downloading image 19 (http://planewave.com/wp-content/uploads/2012/11/85.jpg), type is jpg
# Downloading image 20 (https://live.staticflickr.com/889/41554704295_2093d9fe84_b.jpg), type is jpg
# Downloading image 21 (https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Weinek_Mond-Atlas_T035.jpg/220px-Weinek_Mond-Atlas_T035.jpg), type is jpg
# Downloading image 22 (http://photos1.blogger.com/blogger/5468/437/320/Moon_29-10-template.jpg), type is jpg
# Downloading image 23 (https://c2.staticflickr.com/2/1818/44129017501_afeb205c57_b.jpg), type is jpg
# Downloading image 24 (https://i.ytimg.com/vi/tHnXddhQ71c/hqdefault.jpg), type is jpg
# Downloading image 25 (https://www.cloudynights.com/uploads/monthly_12_2017/post-45396-0-60270800-1514230576.jpg), type is jpg
# could not load : https://www.cloudynights.com/uploads/monthly_12_2017/post-45396-0-60270800-1514230576.jpg
# HTTP Error 403: Forbidden
# Downloading image 26 (https://mk0astronomynow9oh6g.kinstacdn.com/wp-content/uploads/2014/11/Praet_Marnix-Hipparchus_620x450.jpg), type is jpg
# Downloading image 27 (http://cs.astronomy.com/cfs-file.ashx/__key/telligent-evolution-components-attachments/13-62-00-00-00-43-58-62/Albategnius_2D00_09_2D00_11_2D00_24-19_2D00_14_2D00_11_2D00_5L.jpg), type is jpg
# Downloading image 28 (https://live.staticflickr.com/4803/45871371992_231b21f057_b.jpg), type is jpg
# Downloading image 29 (https://farm5.static.flickr.com/4800/25907164057_1ae904cb42_b.jpg), type is jpg
# Downloading image 30 (http://www.muslimheritage.com/uploads/Arabic_names_of_craters.JPG), type is jpg
# Downloading image 31 (http://www.astrosurf.com/cidadao/crater_albategnius_01.jpg), type is jpg
# Downloading image 32 (https://farm8.staticflickr.com/7194/6944576147_fe72be4978_b.jpg), type is jpg
# Downloading image 33 (https://www.skynews.ca/wp-content/uploads/2016/01/Galileo-Moon-1609.jpg), type is jpg
# Downloading image 34 (http://benkolstad.net/wp-content/gallery/moon-shots/moon_20110919.jpg), type is jpg
# Downloading image 35 (http://cs.astronomy.com/cfs-file.ashx/__key/telligent-evolution-components-attachments/13-62-00-00-00-48-10-33/MOnn17122011Albategnius_2800_1_2900_.jpg), type is jpg
# Downloading image 36 (https://d1k5w7mbrh6vq5.cloudfront.net/images/cache/60/b2/83/60b2831aa71af7e4cd897b551a17eca9.jpg), type is jpg
# Downloading image 37 (http://astrofotografie.nl/images/afbeeldingen/crater-albategnius-15-2-2019-r-bosman.jpg), type is jpg
# Downloading image 38 (http://www.astrosurf.com/lunascan/AlbategniusCE.jpg), type is jpg
# Downloading image 39 (http://www.theskyscrapers.org/stuff/contentmgr/files/2/73564371b947983aaeeacfe57a0a84ec/images/first_qtr_moon_with_features_named.jpg), type is jpg
# Downloading image 40 (http://www.ilovestars.com/Images/Moon/Craters/Albategnius-040725-2.jpg), type is jpg
# Downloading image 41 (https://d1k5w7mbrh6vq5.cloudfront.net/images/cache/bc/7b/ae/bc7baed7949ecea4d9d0d7eecb6059cf.jpg), type is jpg
# Downloading image 42 (https://scontent-atl3-1.cdninstagram.com/vp/0e8661543ebe6fdf68944b9ad6bcd206/5D86F7D7/t51.2885-15/e35/57160306_439650150103259_6437748205390725959_n.jpg?_nc_ht=scontent-atl3-1.cdninstagram.com), type is jpg
# Downloading image 43 (http://cs.astronomy.com/cfs-file.ashx/__key/telligent-evolution-components-attachments/13-62-00-00-00-45-88-98/lunanov2010a.jpg), type is jpg
# Downloading image 44 (https://www.skynews.ca/wp-content/uploads/2016/01/Galileo-Moon-art.jpg), type is jpg
# Downloading image 45 (https://cdn10.picryl.com/photo/1969/11/19/as12-51-7471-apollo-12-apollo-12-mission-image-view-of-craters-albategnius-32bfb1-1024.jpg), type is jpg
# Downloading image 46 (https://www.buytelescopes.com/content/images/thumbs/b29e9b30e03c76e81c1ce37e41fe66997279bc1f_x-marks-the-spot-lunar-x-and-craters-albategnius-and-klein.JPG), type is jpg
# Downloading image 47 (http://www.donovanimages.co.nz/media/astrophotography/lunar-landscapes/Albategnius-et-al-3550mmFL-150416.jpg), type is jpg
# Downloading image 48 (http://www.phys.ttu.edu/~ozprof/albateg.jpg), type is jpg
# Downloading image 49 (https://farm1.static.flickr.com/675/31753036796_53c7d3cd30_b.jpg), type is jpg
# Downloading image 50 (https://www.popastro.com/moonwatch/moonweeks/moonmap16.gif), type is gif
# could not load : https://www.popastro.com/moonwatch/moonweeks/moonmap16.gif
# HTTP Error 403: Forbidden
# Downloading image 51 (https://www.3towers.com/3towers_Images/3towersMoon/Images/3towersMoon_WebCam/Lumenera/Albategnius(7_6days).jpg), type is jpg
# Downloading image 52 (http://www.chamaeleon-observatory-onjala.de/en/chamaeleon-observatory/moon-images/mond_web_herbst_2018/einzelbilder/special/albategnius-170251.png), type is png
# Downloading image 53 (https://upload.wikimedia.org/wikipedia/commons/thumb/6/6b/AlbategniusCraterPeak.jpg/270px-AlbategniusCraterPeak.jpg), type is jpg
# Downloading image 54 (http://www.oocities.org/hwy37/moon/albategnius11102005.jpg), type is jpg
# Downloading image 55 (http://www.mystardustobservatory.com/uploads/1/4/1/0/14104820/cratersmoon-nlowndes_orig.jpg), type is jpg
# Downloading image 56 (https://farm66.static.flickr.com/65535/40715854023_70510bfde7_b.jpg), type is jpg
# Downloading image 57 (http://www.orbit.zkm.de/files/the_chesley_bonestell_archives015.jpg), type is jpg
# Downloading image 58 (http://i941.photobucket.com/albums/ad252/lupuvictor/120520114MTS0_08_06002064a.jpg), type is jpg
# Downloading image 59 (http://upload.wikimedia.org/wikipedia/commons/thumb/a/a2/Lunar_Orbiter_4_image_of_Moon_with_Earth.jpg/520px-Lunar_Orbiter_4_image_of_Moon_with_Earth.jpg), type is jpg
# Downloading image 60 (https://d1k5w7mbrh6vq5.cloudfront.net/images/cache/c6/38/ba/c638bae3f68d502068e1e2ba7750be17.jpg), type is jpg
# Downloading image 61 (https://maximusphotography.files.wordpress.com/2018/05/maurolycusstofler.jpg), type is jpg
# Downloading image 62 (http://www.muslimheritage.com/uploads/surface_of_moon.JPG), type is jpg
# Downloading image 63 (http://andrewplanck.com/wp-content/uploads/2018/01/Messier-on-the-Moon-750x350.png), type is png
# could not load : http://andrewplanck.com/wp-content/uploads/2018/01/Messier-on-the-Moon-750x350.png
# HTTP Error 412: Precondition Failed
# Downloading image 64 (https://farm8.static.flickr.com/7211/7178119910_160f6f361c_b.jpg), type is jpg
# Downloading image 65 (https://britastro.org/sites/default/files/styles/xl_image/public/member_images/Albategnius%20%26%20Klein%202017-01-05%201928UT.jpg?itok=kmMIt4R5), type is jpg
# Downloading image 66 (http://www.starfieldobservatory.com/images/18_09_18%20%2020_33_45%20Albategnius%2020%20Def%20100-1apssc.jpg), type is jpg
# Downloading image 67 (https://cdn10.picryl.com/photo/2012/12/31/as14-75-10249-apollo-14-apollo-14-mission-image-view-of-the-albategnius-and-9fd669-1600.jpg), type is jpg
# Downloading image 68 (http://www.madpc.co.uk/~peterl/Moon/Craters/Albategnius041219_18-03-27.jpg), type is jpg
# Downloading image 69 (https://i.etsystatic.com/6132368/r/il/1ad8bc/465614165/il_794xN.465614165_hnso.jpg), type is jpg
# Downloading image 70 (https://media.cheggcdn.com/media%2F69f%2F69f4c3f4-3f2b-47b2-a871-68dbfda2c14b%2Fimage.png), type is png
# Downloading image 71 (https://i.ytimg.com/vi/Ci3ElwLNU48/hqdefault.jpg), type is jpg
# Downloading image 72 (http://mw1.google.com/mw-planetary/lunar/lunarmaps_v1/clem_bw/7/65/59.jpg), type is jpg
# Downloading image 73 (https://d1k5w7mbrh6vq5.cloudfront.net/images/cache/b0/2d/8e/b02d8e5ce10bfe9e4c58bebd9a77ac5c.jpg), type is jpg
# Downloading image 74 (https://c1.staticflickr.com/4/3868/32748483906_78bd51b8e3_b.jpg), type is jpg
# Downloading image 75 (https://scontent-atl3-1.cdninstagram.com/vp/daaa3c1e6a1a4ae9ba8a5baf3874a6b8/5D8FFDC6/t51.2885-15/e35/43778595_149232522702859_379083773687400374_n.jpg?_nc_ht=scontent-atl3-1.cdninstagram.com), type is jpg
# Downloading image 76 (http://www.asod.info/wordpress/wp-content/2012/10/20120626-Albategnius-crater.jpg), type is jpg
# Downloading image 77 (http://www.chamaeleon-observatory-onjala.de/mondatlas-2-en/bilder/2016-7-8-tage-49-5prozent/0032+0033-heraclitus.png), type is png
# Downloading image 78 (http://www.madpc.co.uk/~peterl/Moon/Craters/Albategnius030621Cap08R_W1,2=5.jpg), type is jpg
# Downloading image 79 (https://d1k5w7mbrh6vq5.cloudfront.net/images/cache/61/8c/98/618c9818e030af440065e61fa407bb4c.jpg), type is jpg
# Downloading image 80 (https://www.popastro.com/main_spa1/wp-content/uploads/2019/01/Moon13Jan2000.jpg), type is jpg
# could not load : https://www.popastro.com/main_spa1/wp-content/uploads/2019/01/Moon13Jan2000.jpg
# HTTP Error 403: Forbidden
# Downloading image 81 (https://upload.wikimedia.org/wikipedia/commons/thumb/6/60/Alphonsus_%28LRO%29_1.png/220px-Alphonsus_%28LRO%29_1.png), type is png
# Downloading image 82 (https://millstonenews.com/news/wp-content/uploads/2015/11/theophilusContext1.png), type is png
# Downloading image 83 (https://farm1.static.flickr.com/466/31122515920_e1a2396d90_b.jpg), type is jpg
# Downloading image 84 (http://www.damianpeach.com/barbados09/lunar/albategnius_2009_09_09.jpg), type is jpg
# Downloading image 85 (http://www.thestardeckobservatory.com/The_StarDeckObservatory_Gallery/d/759-2/Lunar_618M-L0002_AG10_2X.jpg), type is jpg
# could not load : http://www.thestardeckobservatory.com/The_StarDeckObservatory_Gallery/d/759-2/Lunar_618M-L0002_AG10_2X.jpg
# HTTP Error 403: Forbidden
# Downloading image 86 (http://muslimheritage.com/sites/default/files/styles/695x421_centered/public/names_of_the_moon_01.jpg?itok=LiGnle2A), type is jpg
# Downloading image 87 (https://image.isu.pub/141027090909-5438c0cc7d6182c1fd8b5430c70128dd/jpg/page_19_thumb_large.jpg), type is jpg
# Downloading image 88 (https://upload.wikimedia.org/wikipedia/commons/8/8a/Albategnius_C_%28AS16-M-2191%29.png), type is png
# Downloading image 89 (https://media.cheggcdn.com/media%2Fe71%2Fe71a7e54-f19d-4d94-8490-bce885e8b112%2Fimage.png), type is png
# Downloading image 90 (http://www.lunar-captures.com/craters_A_files/071002_albategnius_tar.jpg), type is jpg
# Downloading image 91 (http://i941.photobucket.com/albums/ad252/lupuvictor/120520114MTS0_08_06002064.jpg), type is jpg
# Downloading image 92 (https://d1k5w7mbrh6vq5.cloudfront.net/images/cache/b3/b2/41/b3b241b14c6d75735affc2d38d7a6b76.jpg), type is jpg
# Downloading image 93 (http://www.ptobservatory.com/wp-content/uploads/2016/06/Ptolemaeus.jpg), type is jpg
# Downloading image 94 (https://www.cloudynights.com/uploads/monthly_08_2017/post-268046-0-67777600-1502736901.jpg), type is jpg
# could not load : https://www.cloudynights.com/uploads/monthly_08_2017/post-268046-0-67777600-1502736901.jpg
# HTTP Error 403: Forbidden
# Downloading image 95 (http://www.starfieldobservatory.com/images/xxxxx18_01_26%2020_43_45%20Plato%204%20Gauss%20100pscs.jpg), type is jpg
# Downloading image 96 (https://history.nasa.gov/SP-362/p64.jpg), type is jpg
# Downloading image 97 (https://maximusphotography.files.wordpress.com/2018/05/large-area.jpg), type is jpg
# Downloading image 98 (http://www.astrosurf.com/fpertuis/SolarSystem/Albategnius.jpg), type is jpg
# Downloading image 99 (https://www.cityastronomy.com/ptolemaeus-area-title.jpg), type is jpg
# Downloading image 0 (https://upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Aristarchus_crater_hrp162.jpg/240px-Aristarchus_crater_hrp162.jpg), type is jpg
# Downloading image 1 (https://upload.wikimedia.org/wikipedia/commons/thumb/2/22/Aristarchus_satellite_craters.jpg/300px-Aristarchus_satellite_craters.jpg), type is jpg
# Downloading image 2 (https://upload.wikimedia.org/wikipedia/commons/thumb/2/2c/Aristarchus_crater_4150_h3.jpg/240px-Aristarchus_crater_4150_h3.jpg), type is jpg
# Downloading image 3 (https://upload.wikimedia.org/wikipedia/commons/thumb/f/f1/Aristarchus_and_Herodotus_craters_Apollo_15.jpg/240px-Aristarchus_and_Herodotus_craters_Apollo_15.jpg), type is jpg
# Downloading image 4 (https://i1.wp.com/astrobob.areavoices.com/files/2017/03/Aristarchus-March-10.jpg), type is jpg
# Downloading image 5 (https://www.nasa.gov/images/content/519283main_021611b.jpg), type is jpg
# Downloading image 6 (https://upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Aristarchus_hst.jpg/200px-Aristarchus_hst.jpg), type is jpg
# Downloading image 7 (http://www.stargazing.net/david/moon/day13h07M04/n120a50dtext.jpg), type is jpg
# Downloading image 8 (http://lroc.sese.asu.edu/ckeditor_assets/pictures/669/content_as15-m-2610_arist.png), type is png
# Downloading image 9 (http://bartoszwojczynski.com/gallery/full/151124-aristarchus.jpg), type is jpg
# Downloading image 10 (https://www.thelivingmoon.com/43ancients/04images/Moon7/Aristarcus/Aristarcus_MA_03.png), type is png
# Downloading image 11 (https://cdn.mos.cms.futurecdn.net/iRLuV7XuPoDNXLQtw5NHaM-320-80.png), type is png
# Downloading image 12 (https://www.thelivingmoon.com/43ancients/04images/Moon7/Aristarcus/Aristarchus_Sir_Patrick_01.png), type is png
# Downloading image 13 (https://moon.nasa.gov/system/resources/detail_files/347_Aristarchus.jpg), type is jpg
# Downloading image 14 (http://www.fanwave.it/images/foto_articoli/Aristarchus_misteri_lunari/Aristarchus_crater_cover.png), type is png
# Downloading image 15 (https://s22380.pcdn.co/wp-content/uploads/FullMoon_20050918_Frank-Barrett-ST-anno-wide_edited-1.jpg), type is jpg
# Downloading image 16 (https://www.thelivingmoon.com/43ancients/04images/Moon7/Aristarcus/PIA00404_Aristarchus.jpg), type is jpg
# Downloading image 17 (https://i1.wp.com/astrobob.areavoices.com/files/2012/04/Aristarchus-full-moon1-400x304.jpg?resize=350%2C200), type is jpg
# Downloading image 18 (https://www.thelivingmoon.com/43ancients/04images/Moon7/Aristarcus/Aristarcus_CL_02.png), type is png
# Downloading image 19 (https://upload.wikimedia.org/wikipedia/commons/b/b0/Location_of_lunar_aristarchus_crater.jpg), type is jpg
# Downloading image 20 (https://apod.nasa.gov/apod/image/0711/aristarchus_100407friedman.jpg), type is jpg
# Downloading image 21 (https://i.pinimg.com/originals/a0/7c/15/a07c15e94f9ca737492e8e8963caffec.jpg), type is jpg
# Downloading image 22 (https://www.thelivingmoon.com/43ancients/04images/Moon7/Aristarcus/PIA00405_Aristarchus.jpg), type is jpg
# Downloading image 23 (https://www.universetoday.com/wp-content/uploads/2012/12/M1096850878LR_thumb.png), type is png
# could not load : https://www.universetoday.com/wp-content/uploads/2012/12/M1096850878LR_thumb.png
# HTTP Error 403: Forbidden
# Downloading image 24 (https://s22380.pcdn.co/wp-content/uploads/Moon-naked-eye-crater-locator-BKing.jpg), type is jpg
# Downloading image 25 (https://nssdc.gsfc.nasa.gov/imgcat/hires/a15_m_2606.gif), type is gif
# Downloading image 26 (http://files.abovetopsecret.com/files/img/yx590607cf.jpg), type is jpg
# Downloading image 27 (http://lroc.sese.asu.edu/news/uploads/M120161915L_thumb.png), type is png
# Downloading image 28 (https://i0.wp.com/astrobob.areavoices.com/files/2017/03/Aristarchus-Apollo-ANNO-1.jpg), type is jpg
# Downloading image 29 (http://lroc.sese.asu.edu/ckeditor_assets/pictures/663/content_m1259297876_lrmos_1100p_cpeak.png), type is png
# Downloading image 30 (https://i.ytimg.com/vi/KNALrc20jA0/maxresdefault.jpg), type is jpg
# Downloading image 31 (https://www.thelivingmoon.com/43ancients/04images/Moon7/Aristarcus/Aristarcus_LO_01.png), type is png
# Downloading image 32 (https://www.lpi.usra.edu/features/moonVideo/aristarchus.jpg), type is jpg
# Downloading image 33 (https://i2.wp.com/astrobob.areavoices.com/files/2017/03/Aristarchus-LRO-FEA.jpg?resize=750%2C330), type is jpg
# Downloading image 34 (http://cdn.spacetelescope.org/archives/images/screen/opo0529a.jpg), type is jpg
# Downloading image 35 (https://bobmoler.files.wordpress.com/2011/09/moon_09-08-11_22-00.png?w=595), type is png
# Downloading image 36 (http://oldsite.david-tyler.com/images/barbados2006/19-4-06_aristilus_f28.jpg), type is jpg
# Downloading image 37 (http://lroc.sese.asu.edu/news/uploads/M175569775_thumb.png), type is png
# Downloading image 38 (https://i.pinimg.com/originals/0b/ce/ee/0bceee5eb1cdc860f93f0a4ad990516f.jpg), type is jpg
# Downloading image 39 (http://www.stargazing.net/david/moon/day13h7/Dscn3873s565x768ctext.jpg), type is jpg
# Downloading image 40 (https://moonmonday.files.wordpress.com/2019/03/screenshot-from-2019-03-11-20-44-32.png?w=736), type is png
# Downloading image 41 (https://cdn.disclose.tv/sites/default/files/styles/article_image/public/img/post/2017/09/07/video_youtube_ivgHDgklYcs.jpg?itok=RN2mhkib), type is jpg
# Downloading image 42 (https://nssdc.gsfc.nasa.gov/imgcat/hires/clm_usgs_11.gif), type is gif
# Downloading image 43 (https://i.ytimg.com/vi/OIaF-Etc9n4/hqdefault.jpg), type is jpg
# Downloading image 44 (https://www.cloudynights.com/uploads/monthly_11_2013/post-68478-14074201001697_thumb.jpg), type is jpg
# could not load : https://www.cloudynights.com/uploads/monthly_11_2013/post-68478-14074201001697_thumb.jpg
# HTTP Error 403: Forbidden
# Downloading image 45 (http://history.nasa.gov/SP-362/hrp129.jpg), type is jpg
# Downloading image 46 (https://www.lpi.usra.edu/lunar/lunar_flyovers/aristarchus_crater/aristarchus_crater.png), type is png
# Downloading image 47 (https://imgsrc.hubblesite.org/hvi/uploads/image_file/image_attachment/12343/web_print.jpg), type is jpg
# could not load : https://imgsrc.hubblesite.org/hvi/uploads/image_file/image_attachment/12343/web_print.jpg
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:852)>
# Downloading image 48 (http://www.daviddarling.info/images/Aristachus.gif), type is gif
# Downloading image 49 (http://www.spacegrant.hawaii.edu/class_acts/WebImg/Aristarchus.gif), type is gif
# Downloading image 50 (https://bendedreality.com/wp-content/uploads/2017/07/ufo-moon-alien-base-Aristarchus-Crater.jpg), type is jpg
# could not load : https://bendedreality.com/wp-content/uploads/2017/07/ufo-moon-alien-base-Aristarchus-Crater.jpg
# HTTP Error 403: Forbidden
# Downloading image 51 (http://evidenzaliena.altervista.org/wp-content/uploads/2014/12/Aristarchus.jpg), type is jpg
# could not load : http://evidenzaliena.altervista.org/wp-content/uploads/2014/12/Aristarchus.jpg
# HTTP Error 403: Forbidden
# Downloading image 52 (https://live.staticflickr.com/1839/43289026674_74db96c08d_b.jpg), type is jpg
# Downloading image 53 (https://c8.alamy.com/comp/C95B37/aristarchus-region-of-the-moon-C95B37.jpg), type is jpg
# Downloading image 54 (https://anotherglobaleater.files.wordpress.com/2019/03/moonmap.jpg), type is jpg
# Downloading image 55 (http://lroc.sese.asu.edu/news/uploads/M175569775_small.png), type is png
# Downloading image 56 (https://www.thunderbolts.info/tpod/2006/image06/060309hubble.jpg), type is jpg
# Downloading image 57 (https://www.syfy.com/sites/syfy/files/styles/1200x680/public/lro_aristarchus_hero.jpg), type is jpg
# Downloading image 58 (https://i.ytimg.com/vi/wicCfXEVKNw/maxresdefault.jpg), type is jpg
# Downloading image 59 (https://www.syfy.com/sites/syfy/files/styles/1170xauto/public/fredlocklear_fullmoon.jpg), type is jpg
# Downloading image 60 (http://mars.raptorzone.co.za/images/PIA13498_Google_Earth-Large.jpg), type is jpg
# Downloading image 61 (https://cdn.britannica.com/s:500x350/25/76825-004-1950A3F8.jpg), type is jpg
# Downloading image 62 (https://moonmonday.files.wordpress.com/2019/03/aristarchus-crater.png?w=736), type is png
# Downloading image 63 (https://www.nasa.gov/images/content/519278main_021611a.jpg), type is jpg
# Downloading image 64 (https://i.pinimg.com/originals/21/88/26/218826a985b6e3c5d7e2d99a9d3747ee.jpg), type is jpg
# Downloading image 65 (https://planetary.s3.amazonaws.com/assets/images/3-moon/20130826_aristarchus_crater.jpg), type is jpg
# Downloading image 66 (https://upload.wikimedia.org/wikipedia/commons/2/25/Aristarchus_F_crater_5194_med.jpg), type is jpg
# Downloading image 67 (https://farm2.staticflickr.com/1904/45496558001_d33d5f5649_b.jpg), type is jpg
# Downloading image 68 (http://lroc.sese.asu.edu/news/uploads/arist_cpeak_halfres.png), type is png
# Downloading image 69 (https://www.universetoday.com/wp-content/uploads/2010/09/Aristarchus_enhanced_interior_MCollins.jpg), type is jpg
# could not load : https://www.universetoday.com/wp-content/uploads/2010/09/Aristarchus_enhanced_interior_MCollins.jpg
# HTTP Error 403: Forbidden
# Downloading image 70 (https://i.pinimg.com/originals/16/bb/a4/16bba4995bd0ebf3bbd8d417cf56c9c1.jpg), type is jpg
# Downloading image 71 (https://upload.wikimedia.org/wikipedia/commons/6/6e/Vallis_Schroteri.jpg), type is jpg
# Downloading image 72 (https://c8.alamy.com/comp/HRP1TG/the-moons-aristarchus-crater-from-apollo-15-HRP1TG.jpg), type is jpg
# Downloading image 73 (https://i.ytimg.com/vi/Vy-d-fCuGdI/maxresdefault.jpg), type is jpg
# Downloading image 74 (http://jepareg.free.fr/moon/images/ARIS_18_10_1824.jpg), type is jpg
# Downloading image 75 (http://lroc.sese.asu.edu/ckeditor_assets/pictures/653/content_fi_dec18_mz_m181488224re_1kx1k.png), type is png
# Downloading image 76 (https://farm5.staticflickr.com/4259/35707252801_42251e2ede_b.jpg), type is jpg
# Downloading image 77 (https://www.nasa.gov/images/content/470745main_M122523410_lg.jpg), type is jpg
# Downloading image 78 (https://ars.els-cdn.com/content/image/1-s2.0-S0019103517305924-gr10.jpg), type is jpg
# could not load : https://ars.els-cdn.com/content/image/1-s2.0-S0019103517305924-gr10.jpg
# HTTP Error 403: Forbidden
# Downloading image 79 (http://meteomauritius.altervista.org/gallerynew/cache/moon/aristarchus-herodotus_09072014_zwo-asi120mm_203024_r_as_f250_g6_ap141-ps_595.jpg), type is jpg
# Downloading image 80 (https://ars.els-cdn.com/content/image/1-s2.0-S0019103517305924-gr2.jpg), type is jpg
# could not load : https://ars.els-cdn.com/content/image/1-s2.0-S0019103517305924-gr2.jpg
# HTTP Error 403: Forbidden
# Downloading image 81 (http://apollo.sese.asu.edu/LIW/img/20080311_img1.png), type is png
# Downloading image 82 (https://i.ytimg.com/vi/I_bNUmf68g4/maxresdefault.jpg), type is jpg
# Downloading image 83 (https://i.ebayimg.com/images/g/mLUAAOSwB8FbW9Tt/s-l300.jpg), type is jpg
# Downloading image 84 (https://photojournal.jpl.nasa.gov/jpeg/PIA00090.jpg), type is jpg
# Downloading image 85 (https://cdn.spacetelescope.org/archives/images/wallpaper5/opo0529a.jpg), type is jpg
# Downloading image 86 (https://i.ytimg.com/vi/bmt4Qqrhxlw/maxresdefault.jpg), type is jpg
# Downloading image 87 (http://images.spaceref.com/news/2018/oo26560950377.jpg), type is jpg
# Downloading image 88 (https://s22380.pcdn.co/wp-content/uploads/ST-Moon-Hesiodus-A.jpg), type is jpg
# Downloading image 89 (https://www.thunderbolts.info/tpod/2006/image06/060309aristarchus.jpg), type is jpg
# Downloading image 90 (http://andrewplanck.com/wp-content/uploads/2018/12/Seleucus.png), type is png
# could not load : http://andrewplanck.com/wp-content/uploads/2018/12/Seleucus.png
# HTTP Error 412: Precondition Failed
# Downloading image 91 (https://images.metmuseum.org/CRDImages/ph/original/DP-12248-079.jpg), type is jpg
# Downloading image 92 (http://www.salzgeber.at/wordpress/wp-content/uploads/2017/04/Moon_221253_AS_p30_g4_ap1129_wav_1600px.jpg), type is jpg
# Downloading image 93 (https://www.geek.com/wp-content/uploads/2019/01/Aristarchus-625x352.jpg), type is jpg
# Downloading image 94 (https://ichef.bbci.co.uk/images/ic/320x180_b/p01cgfmq.jpg), type is jpg
# Downloading image 95 (http://andrewplanck.com/wp-content/uploads/2017/01/Aristarchus-Plateau.jpg), type is jpg
# could not load : http://andrewplanck.com/wp-content/uploads/2017/01/Aristarchus-Plateau.jpg
# HTTP Error 412: Precondition Failed
# Downloading image 96 (https://www.fossweb.com/delegate/ssi-foss-ucm/Contribution%20Folders/FOSS/multimedia/Planetary_Science/binders/images/main/cm_arist.jpg), type is jpg
# Downloading image 97 (https://thumbor.forbes.com/thumbor/1280x868/https%3A%2F%2Fb-i.forbesimg.com%2Fbrucedorminey%2Ffiles%2F2013%2F03%2F300px-Apollo_15_Aristarchus_Crater1.jpg), type is jpg
# Downloading image 98 (http://www.astroeder.com/rimg/92/485_2038_6e18611b_aristarchus_ederL.jpg), type is jpg
# Downloading image 99 (http://apollo.sese.asu.edu/LIW/img/20090512_img1.png), type is png
# Downloading image 0 (https://www.mariamitchell.org/wp-content/uploads/Moon-with-Mitchell-Crater-f.gif), type is gif
# Downloading image 1 (https://upload.wikimedia.org/wikipedia/commons/thumb/6/66/Aristoteles_crater_4103_h3.jpg/220px-Aristoteles_crater_4103_h3.jpg), type is jpg
# Downloading image 2 (http://i1215.photobucket.com/albums/cc517/lupuvictor1/description%20location%20craters/locationaristoteles.jpg), type is jpg
# Downloading image 3 (https://upload.wikimedia.org/wikipedia/en/thumb/d/d5/Aristoteles_Crater.jpg/220px-Aristoteles_Crater.jpg), type is jpg
# Downloading image 4 (https://nightinfocus.files.wordpress.com/2012/01/halfmoon_withnames.jpg), type is jpg
# Downloading image 5 (https://s3.amazonaws.com/ogden_images/www.adirondackdailyenterprise.com/images/2017/04/11105939/Diagram-962x840.jpg), type is jpg
# Downloading image 6 (http://andrewplanck.com/wp-content/uploads/2018/12/Seleucus.png), type is png
# could not load : http://andrewplanck.com/wp-content/uploads/2018/12/Seleucus.png
# HTTP Error 412: Precondition Failed
# Downloading image 7 (https://nightinfocus.files.wordpress.com/2012/01/img_0174_seas_craters.jpg), type is jpg
# Downloading image 8 (https://i.ytimg.com/vi/i8ygRKCKK9A/maxresdefault.jpg), type is jpg
# Downloading image 9 (http://andrewplanck.com/wp-content/uploads/2018/10/moon-craters-Aristoteles-and-Eudoxus.png), type is png
# could not load : http://andrewplanck.com/wp-content/uploads/2018/10/moon-craters-Aristoteles-and-Eudoxus.png
# HTTP Error 412: Precondition Failed
# Downloading image 10 (http://galileo.rice.edu/images/things/cassini_moon.gif), type is gif
# Downloading image 11 (http://1.bp.blogspot.com/-SFUnntSWFCE/VhnzuXnxAkI/AAAAAAAAKTI/fluDz3gctV0/s1600/Eudoxus_-_LROC_-_WAC.JPG), type is jpg
# Downloading image 12 (http://3.bp.blogspot.com/-5TLFet9uFhg/VmQ5bGt_PaI/AAAAAAAAChI/jZ4xidhwXBw/s1600/MM1.jpg), type is jpg
# Downloading image 13 (http://andrewplanck.com/wp-content/uploads/2019/03/Both-Eudoxus-and-Aristoteles-to-its-north-are-wonderfully-complex-craters-with-terraced-walls-640x350.png), type is png
# could not load : http://andrewplanck.com/wp-content/uploads/2019/03/Both-Eudoxus-and-Aristoteles-to-its-north-are-wonderfully-complex-craters-with-terraced-walls-640x350.png
# HTTP Error 412: Precondition Failed
# Downloading image 14 (https://i.pinimg.com/originals/0e/1d/40/0e1d40400d2311e1572caecdb6e5ed12.jpg), type is jpg
# Downloading image 15 (http://mvas.org/files/images/AristotelesCrater_ChumackLRweb.preview.jpg), type is jpg
# Downloading image 16 (http://galileo.rice.edu/images/things/hevelius_moon_r.gif), type is gif
# Downloading image 17 (https://www.wfyi.org/files/wfyi/programs_radio/current/gibbous-moon.jpg), type is jpg
# Downloading image 18 (http://galileo.rice.edu/images/things/g_moonwash.gif), type is gif
# Downloading image 19 (http://galileo.rice.edu/images/things/moonsketch.gif), type is gif
# Downloading image 20 (https://live.staticflickr.com/6171/6156419363_c7992b239a_b.jpg), type is jpg
# Downloading image 21 (http://www.astronoo.com/images/planetes/lune/cratere-de-la-lune-leibnitz.jpg), type is jpg
# Downloading image 22 (https://metode.cat/wp-content/uploads/2012/04/23-73.jpg), type is jpg
# Downloading image 23 (https://static.uglyhedgehog.com/upload/2012/5/6/thumb-1336339747094-crater_map.jpg), type is jpg
# Downloading image 24 (http://i941.photobucket.com/albums/ad252/lupuvictor/astro%202012/27042012astronomytelescopeimagesmooncraters31.jpg), type is jpg
# Downloading image 25 (https://images.theconversation.com/files/28369/original/rqkwdwcx-1375195450.jpg?ixlib=rb-1.1.0&q=45&auto=format&w=1356&h=668&fit=crop), type is jpg
# Downloading image 26 (https://www.libson-yarker.com/downloads/images/Nasmyth---The-surface-of-the-moon-showing-the-craters-Aristotle-and-Eudoxus.jpg), type is jpg
# Downloading image 27 (http://i1215.photobucket.com/albums/cc517/lupuvictor1/aristotellesandeuxodus.jpg), type is jpg
# Downloading image 28 (https://3c1703fe8d.site.internapcdn.net/newman/csz/news/800/2015/2-themoon.jpg), type is jpg
# Downloading image 29 (http://www.astronoo.com/images/planetes/lune/cratere-arzachel.jpg), type is jpg
# Downloading image 30 (http://2.bp.blogspot.com/-OalPSnbn5GI/VmQzhyg2yPI/AAAAAAAACgo/wdyCXszix8M/s1600/MM2.jpg), type is jpg
# Downloading image 31 (https://images.slideplayer.com/18/6091076/slides/slide_5.jpg), type is jpg
# Downloading image 32 (http://www.astronoo.com/images/planetes/lune/cratere-lunaire-clavius.jpg), type is jpg
# Downloading image 33 (http://i941.photobucket.com/albums/ad252/lupuvictor/astro%202012/27042012astronomytelescopeimagesmooncraters77.jpg), type is jpg
# Downloading image 34 (http://tomblackson.com/Ancient/Aristotle_crater.jpg), type is jpg
# Downloading image 35 (https://wp-media.patheos.com/blogs/sites/384/2014/10/nasa_moon_crater_302.jpg), type is jpg
# Downloading image 36 (https://cosmicpursuits.com/wp-content/uploads/2019/03/Lunar-Tour-First-Quarter.png), type is png
# could not load : https://cosmicpursuits.com/wp-content/uploads/2019/03/Lunar-Tour-First-Quarter.png
# HTTP Error 403: Forbidden
# Downloading image 37 (https://upcosmos.com/wp-content/uploads/2018/03/Moon-map-with-sea-mountain-crater-locations-and-names.jpg), type is jpg
# could not load : https://upcosmos.com/wp-content/uploads/2018/03/Moon-map-with-sea-mountain-crater-locations-and-names.jpg
# HTTP Error 403: Forbidden
# Downloading image 38 (https://i1.wp.com/on-walkabout.net/wp-content/uploads/2016/05/Screen-Shot-2016-05-29-at-3.25.15-PM.png?fit=1200%2C617&ssl=1&resize=350%2C200), type is png
# Downloading image 39 (http://www.masdingastronomy.com/wp-content/uploads/2018/05/Aristotle-Eudoxus-20180522.jpg), type is jpg
# Downloading image 40 (http://andrewplanck.com/wp-content/uploads/2018/05/crater-Tycho.png), type is png
# could not load : http://andrewplanck.com/wp-content/uploads/2018/05/crater-Tycho.png
# HTTP Error 412: Precondition Failed
# Downloading image 41 (https://d1k5w7mbrh6vq5.cloudfront.net/images/cache/30/8e/27/308e2797d5a60f5f01450d0026c5d6f9.jpg), type is jpg
# Downloading image 42 (https://img.yumpu.com/5724199/1/500x640/observatorio-arval-moon-map.jpg), type is jpg
# Downloading image 43 (http://galileo.rice.edu/images/things/malapertmoon.bmp), type is bmp
# Downloading image 44 (http://i1215.photobucket.com/albums/cc517/lupuvictor1/Lunar%20images%202012/2904201210MTS0_03_56000523_zpsc552d246.jpg), type is jpg
# Downloading image 45 (https://www.universetoday.com/wp-content/uploads/2009/11/Copernicus_LRO_2.png), type is png
# could not load : https://www.universetoday.com/wp-content/uploads/2009/11/Copernicus_LRO_2.png
# HTTP Error 403: Forbidden
# Downloading image 46 (https://metode.cat/wp-content/uploads/2012/04/27i28-73.jpg), type is jpg
# Downloading image 47 (https://compote.slate.com/images/45ef1443-d734-4e4f-a767-0cb0fdaa7963.jpg), type is jpg
# Downloading image 48 (https://d1k5w7mbrh6vq5.cloudfront.net/images/cache/f5/b8/86/f5b886eb0509f1648affceda8b54fa0d.jpg), type is jpg
# Downloading image 49 (https://www.universetoday.com/wp-content/uploads/2011/10/Moon-milo.jpg), type is jpg
# could not load : https://www.universetoday.com/wp-content/uploads/2011/10/Moon-milo.jpg
# HTTP Error 403: Forbidden
# Downloading image 50 (https://cdn.hswstatic.com/gif/moon-1.jpg), type is jpg
# Downloading image 51 (https://planetarymapping.files.wordpress.com/2015/11/1610_galileo.jpg), type is jpg
# Downloading image 52 (http://www.starfieldobservatory.com/images/2018_07_18%2017_19_14%2020%20Gutenberg%20Def%20100-1psb.jpg), type is jpg
# Downloading image 53 (https://i.vimeocdn.com/video/676642437.webp?mw=1000&mh=563&q=70), type is webp
# Downloading image 54 (https://i.pinimg.com/originals/88/fa/d8/88fad8a9b6e44b9c1623ba9adc7dc9d7.jpg), type is jpg
# Downloading image 55 (https://moon.lindahall.org/images/952/moon1101.jpg), type is jpg
# Downloading image 56 (http://www.charmingglobe.com/system_dntb/upload/image/20171110/20171110095615_1424.png), type is png
# Downloading image 57 (https://upload.wikimedia.org/wikipedia/commons/e/e1/FullMoon2010.jpg), type is jpg
# Downloading image 58 (https://s22380.pcdn.co/wp-content/uploads/2018-07-29_5b5e3f227d319_ARISTOTELES_EUDOXUSJPG.jpg), type is jpg
# Downloading image 59 (https://upload.wikimedia.org/wikipedia/commons/thumb/e/e8/Moon%27s_impact_crater_Tycho.jpg/220px-Moon%27s_impact_crater_Tycho.jpg), type is jpg
# Downloading image 60 (http://galileo.rice.edu/images/things/gilbert_moon.gif), type is gif
# Downloading image 61 (http://blog.hmns.org/wp-content/uploads/2019/04/moon4-1024x695.jpg), type is jpg
# Downloading image 62 (http://mo-www.harvard.edu/microobs/guestobserverportal/Galileo/ThenNow/Moon/mObsMoonWeb_files/image007.jpg), type is jpg
# Downloading image 63 (https://bigthink-img.rbl.ms/simage/https%3A%2F%2Fassets.rbl.ms%2F18624074%2F980x.jpg/2000%2C2000/K7PRisDqqswZ8IrI/img.jpg), type is jpg
# Downloading image 64 (https://i.pinimg.com/236x/fa/d8/1e/fad81e35747d8c43ce98b4a9df1468dd.jpg), type is jpg
# Downloading image 65 (https://images.theconversation.com/files/96166/original/image-20150925-16033-1h2z2f.jpg?ixlib=rb-1.1.0&q=45&auto=format&w=1012&h=668&fit=crop), type is jpg
# Downloading image 66 (http://www.starfieldobservatory.com/images/xxxxx%2017-08-04%2019_53_26%20Clavius%2015%20Gauss%20100s.jpg), type is jpg
# Downloading image 67 (https://s3.amazonaws.com/gs-waymarking-images/b957f5c2-99fd-43bd-b18b-39329cefd4e7.jpg), type is jpg
# Downloading image 68 (https://i.redd.it/e864sr8frkq01.png), type is png
# Downloading image 69 (http://galileo.rice.edu/lib/student_work/astronomy95/astrogrobs/sm2.moon1.gif), type is gif
# Downloading image 70 (https://www.jpl.nasa.gov/edu/images/activities/superbloodmoon.png), type is png
# Downloading image 71 (http://www.chamaeleon-observatory-onjala.de/mondatlas-2-en/bilder/74prozent/mosaik/bullialdus-1+3+4.png), type is png
# Downloading image 72 (https://www.rd.com/wp-content/uploads/2018/06/02-1.jpg), type is jpg
# could not load : https://www.rd.com/wp-content/uploads/2018/06/02-1.jpg
# HTTP Error 403: Forbidden
# Downloading image 73 (https://d1k5w7mbrh6vq5.cloudfront.net/images/cache/d2/5e/f4/d25ef4254c1547cdca61f4e99429d9a4.jpg), type is jpg
# Downloading image 74 (https://thumbs-prod.si-cdn.com/kwbBFqcn4UJOxWb4Bw3lhVCirvo=/fit-in/1072x0/filters:focal(534x509:535x510)/https://public-media.si-cdn.com/filer/18/01/18014164-a386-4985-9885-55f1c5f5c749/anaxagoras_crater_4128_h2.jpg), type is jpg
# could not load : https://thumbs-prod.si-cdn.com/kwbBFqcn4UJOxWb4Bw3lhVCirvo=/fit-in/1072x0/filters:focal(534x509:535x510)/https://public-media.si-cdn.com/filer/18/01/18014164-a386-4985-9885-55f1c5f5c749/anaxagoras_crater_4128_h2.jpg
# HTTP Error 403: Forbidden
# Downloading image 75 (http://www.starfieldobservatory.com/images/xxxxx18_01_26%2020_43_45%20Plato%204%20Gauss%20100pscs.jpg), type is jpg
# Downloading image 76 (http://galileo.rice.edu/images/things/g_sidnun_moon-t.gif), type is gif
# Downloading image 77 (http://andrewplanck.com/wp-content/uploads/2017/11/Pitatus.png), type is png
# could not load : http://andrewplanck.com/wp-content/uploads/2017/11/Pitatus.png
# HTTP Error 412: Precondition Failed
# Downloading image 78 (http://i1215.photobucket.com/albums/cc517/lupuvictor1/Registax%20pictures/19200720112644fr90sua.jpg), type is jpg
# Downloading image 79 (https://theloaferonline.com/wp-content/uploads/2017/06/Stargazer.jpg), type is jpg
# Downloading image 80 (https://compote.slate.com/images/eaa6a645-3fb2-48ca-8304-2582a086fb3d.jpg), type is jpg
# Downloading image 81 (http://www.starfieldobservatory.com/images/xxx%202018_07_18%2017_48_45%205%20Vallis%20Rheita%20Def%20100-3cs1.jpg), type is jpg
# Downloading image 82 (https://i0.wp.com/farm1.staticflickr.com/712/32047895801_3014669b17_c.jpg?resize=640%2C386), type is jpg
# Downloading image 83 (https://en.pimg.jp/039/625/967/1/39625967.jpg), type is jpg
# Downloading image 84 (http://www.thestargarden.co.uk/Images/Heliocentrism-heliocentric-Cellarius.jpg), type is jpg
# Downloading image 85 (https://learnodo-newtonic.com/wp-content/uploads/2019/03/Aristotle-Contributions-Featured.jpg), type is jpg
# Downloading image 86 (http://galileo.rice.edu/images/things/mellan2.bmp), type is bmp
# Downloading image 87 (http://blog.hmns.org/wp-content/uploads/2019/05/moon1-1-964x1024.jpg), type is jpg
# Downloading image 88 (https://www.readersdigest.ca/wp-content/uploads/sites/14/2018/06/moon-mysteries.jpg), type is jpg
# could not load : https://www.readersdigest.ca/wp-content/uploads/sites/14/2018/06/moon-mysteries.jpg
# HTTP Error 403: Forbidden
# Downloading image 89 (http://i26.photobucket.com/albums/c122/joeparis/compmoonmontage.jpg), type is jpg
# Downloading image 90 (https://cdn.cnn.com/cnnnext/dam/assets/140716163853-lunar-topographic-map-horizontal-large-gallery.jpg), type is jpg
# Downloading image 91 (https://thumbor.forbes.com/thumbor/960x0/https%3A%2F%2Fblogs-images.forbes.com%2Fthelabbench%2Ffiles%2F2017%2F07%2FGalileo-Moon-e1500561695334.jpg), type is jpg
# Downloading image 92 (https://d1k5w7mbrh6vq5.cloudfront.net/images/cache/69/b1/72/69b17233af3ab5bcf2f68dbe0de8b50b.jpg), type is jpg
# Downloading image 93 (http://www.physast.uga.edu/~rls/astro1020/figures/ch03_fig3_9.jpg), type is jpg
# Downloading image 94 (http://www.astronoo.com/images/planetes/lune/detail-de-la-lune.jpg), type is jpg
# Downloading image 95 (http://www.charmingglobe.com/system_dntb/upload/image/20171110/20171110100132_0704.jpg), type is jpg
# Downloading image 96 (http://web.mnstate.edu/colson/est/Image17.jpg), type is jpg
# Downloading image 97 (https://media.treehugger.com/assets/images/2019/01/redmoon-super.jpg.860x0_q70_crop-scale.jpg), type is jpg
# Downloading image 98 (https://d1k5w7mbrh6vq5.cloudfront.net/images/cache/44/cc/b0/44ccb0eda2b598ac25ec3397fa4f5b02.jpg), type is jpg
# Downloading image 99 (https://i.pinimg.com/236x/18/3d/e6/183de64076d507d9c6379fcc98801702.jpg), type is jpg
# Downloading image 0 (https://upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Bailly-large.jpg/220px-Bailly-large.jpg), type is jpg
# Downloading image 1 (https://upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Bailly_%28LRO%29.png/220px-Bailly_%28LRO%29.png), type is png
# Downloading image 2 (https://upload.wikimedia.org/wikipedia/commons/thumb/e/eb/Bailly_crater_4179_h2_h3.jpg/220px-Bailly_crater_4179_h2_h3.jpg), type is jpg
# Downloading image 3 (http://0e33611cb8e6da737d5c-e13b5a910e105e07f9070866adaae10b.r15.cf1.rackcdn.com/Philip-Smith-Moon-Slice-6-29-15_1436990923_lg.png), type is png
# Downloading image 4 (https://www.cloudynights.com/uploads/monthly_10_2018/post-263915-0-86670000-1539251909.jpg), type is jpg
# could not load : https://www.cloudynights.com/uploads/monthly_10_2018/post-263915-0-86670000-1539251909.jpg
# HTTP Error 403: Forbidden
# Downloading image 5 (https://upload.wikimedia.org/wikipedia/commons/6/6f/Location_of_lunar_bailly_crater.jpg), type is jpg
# Downloading image 6 (http://www.daviddarling.info/images2/Bailly_crater.jpg), type is jpg
# Downloading image 7 (https://upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Bailly_%28LRO%29.png/200px-Bailly_%28LRO%29.png), type is png
# Downloading image 8 (http://www.damianpeach.com/barbados09/lunar/moretus_rgb_2009_09_09.jpg), type is jpg
# Downloading image 9 (https://www.cloudynights.com/uploads/monthly_09_2004/post-4199-14070916871526_thumb.jpg), type is jpg
# could not load : https://www.cloudynights.com/uploads/monthly_09_2004/post-4199-14070916871526_thumb.jpg
# HTTP Error 403: Forbidden
# Downloading image 10 (https://live.staticflickr.com/1517/26568185136_2a5a589027_b.jpg), type is jpg
# Downloading image 11 (https://i1.wp.com/www.williamwinters.com/wp-content/uploads/2018/07/MOON-26JUL2018.jpg), type is jpg
# Downloading image 12 (https://upload.wikimedia.org/wikipedia/commons/thumb/d/df/Bettinus_crater_4154_h3.jpg/250px-Bettinus_crater_4154_h3.jpg), type is jpg
# Downloading image 13 (https://yourmajestylipbalm.files.wordpress.com/2017/12/shutterstock_248399605.jpg?w=660&h=330&crop=1), type is jpg
# Downloading image 14 (https://farm5.staticflickr.com/4193/33757660653_3c831d7536_b.jpg), type is jpg
# Downloading image 15 (http://www.footootjes.nl/Astrophotography_Lunar/20071222_Bailly_OF_64G180_f22Grad256MAP9_20_wv1.jpg), type is jpg
# Downloading image 16 (https://farm1.staticflickr.com/675/32956015002_fe99870439_b.jpg), type is jpg
# Downloading image 17 (http://chamaeleon-observatory-onjala.de/en/chamaeleon-observatory/moon-images/mond_web_2014/bilder-23-04/kop+reinhold-14-04-23%2008-41-17_ut-+text.png), type is png
# Downloading image 18 (http://www.salzgeber.at/astro/moon/theophilus_montes_altai.jpg), type is jpg
# Downloading image 19 (https://live.staticflickr.com/4183/34437600341_0963af2bd1_b.jpg), type is jpg
# Downloading image 20 (http://www.damianpeach.com/barbados09/lunar/copernicus_2009_08_29.jpg), type is jpg
# Downloading image 21 (http://www.footootjes.nl/Astrophotography_Lunar/20070328_Clavius_B_RF_27G700_f53Grad256map10_20_wv34_mirror_1016x762.jpg), type is jpg
# Downloading image 22 (https://the-moon.us/images/6/68/Humboldt.jpg), type is jpg
# Downloading image 23 (https://upload.wikimedia.org/wikipedia/commons/8/85/Bailly_sattelite_craters_map.jpg), type is jpg
# Downloading image 24 (x-raw-image:///db5ef24445662d50015e31f8c4a961f1fbe51800492e3d1c4608c1c4233aefbf), type is jpg
# could not load : x-raw-image:///db5ef24445662d50015e31f8c4a961f1fbe51800492e3d1c4608c1c4233aefbf
# <urlopen error unknown url type: x-raw-image>
# Downloading image 25 (https://c8.alamy.com/comp/MR6KBP/engraving-depicting-a-section-of-the-moon-in-the-region-of-the-crater-bailly-dated-19th-century-MR6KBP.jpg), type is jpg
# Downloading image 26 (http://jsmastronomy.30143.n7.nabble.com/file/n1707/bailly-detail1_1x.jpg), type is jpg
# Downloading image 27 (http://i1215.photobucket.com/albums/cc517/lupuvictor1/moon%202011/120820115MTS0_04_43002551.jpg), type is jpg
# Downloading image 28 (http://photo.accuweather.com/photogallery/2008/4/500/bd6f4c2a2.jpg), type is jpg
# Downloading image 29 (http://i1215.photobucket.com/albums/cc517/lupuvictor1/moon%202011/00000MTS0_01_21002540.jpg), type is jpg
# Downloading image 30 (http://upload.wikimedia.org/wikipedia/commons/8/85/AS10-29-4324.jpg), type is jpg
# Downloading image 31 (https://ase.tufts.edu/cosmos/pictures/Explore_figs_8/Chapter5/Fig5_8copy.jpg), type is jpg
# Downloading image 32 (http://mw1.google.com/mw-planetary/lunar/lunarmaps_v1/clem_bw/7/39/31.jpg), type is jpg
# Downloading image 33 (https://maas.museum/app/uploads/sites/6/2006/10/xbailly-s.jpg.pagespeed.ic.LoI1Z9vOG-.jpg), type is jpg
# Downloading image 34 (https://lovethenightsky.com/wp-content/uploads/2019/04/moon-508756_640.jpg), type is jpg
# Downloading image 35 (http://www.ap-i.net/avl/doc/Archimedes_T1MPDM.jpg), type is jpg
# Downloading image 36 (https://upload.wikimedia.org/wikipedia/commons/thumb/6/6d/Hausen_LROC.jpg/220px-Hausen_LROC.jpg), type is jpg
# Downloading image 37 (https://michaelmc.typepad.com/.a/6a0147e271cdbe970b01543556092e970c-500wi), type is jpg
# Downloading image 38 (http://www.weasner.com/co/Reports/2017/08/06/Cas_Obs_iPhone_080517-3.jpg), type is jpg
# Downloading image 39 (https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Albategnius_crater_4101_h2_h3.jpg/220px-Albategnius_crater_4101_h2_h3.jpg), type is jpg
# Downloading image 40 (https://maximusphotography.files.wordpress.com/2018/04/the-south.jpg), type is jpg
# Downloading image 41 (http://www.sterntaucher.net/Bilder/lunar100_83_PlatoCraterlets.jpg), type is jpg
# Downloading image 42 (https://www2.lpod.org/images/3/39/LPOD-Aug11-08.jpg), type is jpg
# Downloading image 43 (https://d1k5w7mbrh6vq5.cloudfront.net/images/cache/6b/64/bb/6b64bb9cad2bb15ae2f2e7ccc4e52ae0.jpg), type is jpg
# Downloading image 44 (http://www.damianpeach.com/barbados09/lunar/albategnius_2009_09_09.jpg), type is jpg
# Downloading image 45 (http://zimmer.csufresno.edu/~fringwal/ToUcam-Moon-Gassendi-2006-05-08-f20-125s-9of2822-unsharp.jpg), type is jpg
# Downloading image 46 (https://upload.wikimedia.org/wikipedia/commons/e/e8/Moon%27s_impact_crater_Tycho.jpg), type is jpg
# Downloading image 47 (http://astronomy.swin.edu.au/sao/imagegallery/full_moon_tim_hunter.jpg), type is jpg
# Downloading image 48 (http://www.madpc.co.uk/~peterl/Moon/Craters/Bailly050831_04-39-18.jpg), type is jpg
# Downloading image 49 (https://i.pinimg.com/236x/46/36/2d/46362d7ed78ac7959982a92604501f9e--on-the-moon-bruno.jpg), type is jpg
# Downloading image 50 (https://britastro.org/sites/default/files/Bailly%20on%20terminator%202.jpg), type is jpg
# Downloading image 51 (https://farm5.static.flickr.com/4153/5100706044_f8359e24ce_b.jpg), type is jpg
# Downloading image 52 (http://www.asod.info/wordpress/wp-content/2014/08/Bailly-and-Region-726x1024.jpg), type is jpg
# Downloading image 53 (https://britastro.org/sites/default/files/Moon2019-04-17-2313-DLA.jpg), type is jpg
# Downloading image 54 (http://www.damianpeach.com/barbados09/lunar/drygalski_2009_09_09.jpg), type is jpg
# Downloading image 55 (https://l450v.alamy.com/450v/mr6kcc/engraving-depicting-a-section-of-the-moon-in-the-region-of-mare-imbrium-with-details-showing-craters-newton-and-plato-under-different-lighting-conditions-dated-18th-century-mr6kcc.jpg), type is jpg
# ...
# Downloading image 33 (http://i1215.photobucket.com/albums/cc517/lupuvictor1/Moon%20telescope%202012/locationmaniliusjuliuscaesarcratersastronomymoontelescope.jpg), type is jpg
# Downloading image 34 (https://schmidling.com/plinius.jpg), type is jpg
# Downloading image 35 (https://upload.wikimedia.org/wikipedia/commons/thumb/f/f3/Dawes_crater_AS17-P-2762.jpg/220px-Dawes_crater_AS17-P-2762.jpg), type is jpg
# Downloading image 36 (https://www.cloudynights.com/uploads/monthly_05_2015/post-17157-0-20829200-1432605740.jpg), type is jpg
# could not load : https://www.cloudynights.com/uploads/monthly_05_2015/post-17157-0-20829200-1432605740.jpg
# HTTP Error 403: Forbidden
# Downloading image 37 (https://s22380.pcdn.co/wp-content/uploads/Lunar-craters-for-timing.jpg), type is jpg
# Downloading image 38 (https://www.cloudynights.com/uploads/monthly_02_2019/post-17157-0-63330200-1550450734.jpg), type is jpg
# could not load : https://www.cloudynights.com/uploads/monthly_02_2019/post-17157-0-63330200-1550450734.jpg
# HTTP Error 403: Forbidden
# Downloading image 39 (http://andrewplanck.com/wp-content/uploads/2019/02/Can-you-see-the-American-flag-on-the-moon.jpg), type is jpg
# could not load : http://andrewplanck.com/wp-content/uploads/2019/02/Can-you-see-the-American-flag-on-the-moon.jpg
# HTTP Error 412: Precondition Failed
# Downloading image 40 (https://i.pinimg.com/originals/d1/8d/99/d18d99064c48830cd265b0e94deb91b4.jpg), type is jpg
# Downloading image 41 (https://cdn10.picryl.com/photo/1971/08/02/as15-90-12326-apollo-15-apollo-15-mission-image-view-of-craters-tacquet-a-maclear-7ad975-1600.jpg), type is jpg
# Downloading image 42 (https://upload.wikimedia.org/wikipedia/commons/thumb/e/e8/Moon%27s_impact_crater_Tycho.jpg/220px-Moon%27s_impact_crater_Tycho.jpg), type is jpg
# Downloading image 43 (https://cdn10.picryl.com/photo/1971/08/02/as15-81-10953-apollo-15-apollo-15-mission-image-view-north-of-plinius-crater-d7efa3-1600.jpg), type is jpg
# Downloading image 44 (http://roslistonastronomy.uk/wp-content/uploads/2017/11/Plinius_Samworth-c_251117.jpg), type is jpg
# Downloading image 45 (https://stargazerslounge.com/applications/core/interface/imageproxy/imageproxy.php?img=http://i.imgur.com/TxSY3Kw.jpg?1&key=f3c8df24e1bbe73a6d92d6c9861cf7b1bbf6a1833fb121be687a42946be85b3f), type is php
# Downloading image 46 (http://andrewplanck.com/wp-content/uploads/2019/04/Moon-crater-Gutenberg-750x350.png), type is png
# could not load : http://andrewplanck.com/wp-content/uploads/2019/04/Moon-crater-Gutenberg-750x350.png
# HTTP Error 412: Precondition Failed
# Downloading image 47 (https://upload.wikimedia.org/wikipedia/commons/thumb/5/56/Plinius_crater_as10-31-4599.jpg/440px-Plinius_crater_as10-31-4599.jpg), type is jpg
# Downloading image 48 (https://schmidling.com/cath.jpg), type is jpg
# Downloading image 49 (https://stargazerslounge.com/applications/core/interface/imageproxy/imageproxy.php?img=http://i.imgur.com/yCaU1jQ.jpg?2&key=26e630266fde2dd5a14b1efaf03f7265ecb921f8359299fe7bfa69a4986d3f28), type is php
# Downloading image 50 (https://s22380.pcdn.co/wp-content/uploads/FullMoonSeronik_m.jpg), type is jpg
# Downloading image 51 (https://upload.wikimedia.org/wikipedia/commons/1/16/Webb_crater.png), type is png
# Downloading image 52 (https://i.pinimg.com/originals/64/3b/0e/643b0eaa0b46a736d24f2bab748b63ae.jpg), type is jpg
# Downloading image 53 (https://cdn10.picryl.com/photo/1972/12/12/as17-150-23069-apollo-17-apollo-17-moon-plinius-rilles-ad83c7-1600.jpg), type is jpg
# Downloading image 54 (https://upload.wikimedia.org/wikipedia/commons/a/a3/AS10-31-4599_Carrel_Plinius_craters.jpg), type is jpg
# Downloading image 55 (http://i1215.photobucket.com/albums/cc517/lupuvictor1/description%20location%20craters/descriptionlocationpliniuscrater20072011.jpg), type is jpg
# Downloading image 56 (x-raw-image:///546e7bf3695b22250ef6746dcbe182f834db8ab19186c63fc420cceadf818f13), type is jpg
# could not load : x-raw-image:///546e7bf3695b22250ef6746dcbe182f834db8ab19186c63fc420cceadf818f13
# <urlopen error unknown url type: x-raw-image>
# Downloading image 57 (http://tocobs.org/moon/moplin.jpg), type is jpg
# Downloading image 58 (http://mw1.google.com/mw-planetary/lunar/lunarmaps_v1/clem_bw/7/72/70.jpg), type is jpg
# Downloading image 59 (http://andrewplanck.com/wp-content/uploads/2017/06/Mons-Delisle-and-Kepler-moon-crater.png), type is png
# could not load : http://andrewplanck.com/wp-content/uploads/2017/06/Mons-Delisle-and-Kepler-moon-crater.png
# HTTP Error 412: Precondition Failed
# Downloading image 60 (https://s22380.pcdn.co/wp-content/uploads/Garnder-megadome-BEST-WPaesch.jpg), type is jpg
# Downloading image 61 (https://media.springernature.com/lw785/springer-static/image/chp%3A10.1007%2F978-3-642-14805-7_6/MediaObjects/978-3-642-14805-7_6_Fig23_HTML.gif), type is gif
# Downloading image 62 (https://www.cloudynights.com/uploads/monthly_03_2018/post-211131-0-03532200-1521826036.jpg), type is jpg
# could not load : https://www.cloudynights.com/uploads/monthly_03_2018/post-211131-0-03532200-1521826036.jpg
# HTTP Error 403: Forbidden
# Downloading image 63 (https://media.springernature.com/lw785/springer-static/image/chp%3A10.1007%2F978-3-642-14805-7_6/MediaObjects/978-3-642-14805-7_6_Fig5_HTML.gif), type is gif
# Downloading image 64 (http://i1215.photobucket.com/albums/cc517/lupuvictor1/Lunar%20images%202012/29042012lunappppppppppppppppp_zps44d49f1b.jpg), type is jpg
# Downloading image 65 (https://observatory.astro.utah.edu/pics/paul/moon%20piluinasX-352.JPG), type is jpg
# Downloading image 66 (http://tocobs.org/moon/moaris.jpg), type is jpg
# Downloading image 67 (https://usercontent2.hubstatic.com/5906693_f520.jpg), type is jpg
# could not load : https://usercontent2.hubstatic.com/5906693_f520.jpg
# HTTP Error 403: Forbidden
# Downloading image 68 (http://moon.scopesandscapes.com/TLO-images/2018-09/2018-07-27_22-15-44Langrenus.JPG), type is jpg
# Downloading image 69 (https://i.pinimg.com/originals/74/39/3e/74393ede1bf0d6f58388aa05a1626c0e.jpg), type is jpg
# Downloading image 70 (https://i1.wp.com/astrobob.areavoices.com/files/2017/11/Apollo-17-wide-locator-v2.jpg), type is jpg
# Downloading image 71 (https://s22380.pcdn.co/wp-content/uploads/Domes-Hortensius-Mike-Wirths-ST.jpg), type is jpg
# Downloading image 72 (http://www.chamaeleon-observatory-onjala.de/mondatlas-en/bilder-vulkanismus/s05/s5a/6-1-tage/gardner-apollo17-0009.png), type is png
# Downloading image 73 (https://cdn10.picryl.com/photo/1972/12/12/as17-150-23067-apollo-17-apollo-17-moon-dawes-plinius-rilles-3d3126-1600.jpg), type is jpg
# Downloading image 74 (https://schmidling.com/copf.jpg), type is jpg
# Downloading image 75 (https://upload.wikimedia.org/wikipedia/commons/thumb/f/fc/Dawes_crater_moon.jpg/320px-Dawes_crater_moon.jpg), type is jpg
# Downloading image 76 (http://i941.photobucket.com/albums/ad252/lupuvictor/Registax%20gallery/luna029042012d145fr85sub_zpsb8975f6a.png), type is png
# Downloading image 77 (https://farm3.static.flickr.com/2817/12341532954_5063b67382_b.jpg), type is jpg
# Downloading image 78 (https://the-moon.us/images/3/39/Normal_Rimae-Plinius_LO-IV-085H_LTVT.JPG), type is jpg
# Downloading image 79 (https://live.staticflickr.com/4276/34534654503_17370037ed_b.jpg), type is jpg
# Downloading image 80 (http://tocobs.org/moon/moburg.jpg), type is jpg
# Downloading image 81 (https://i.pinimg.com/originals/09/07/ee/0907ee071319be76f5357e534846ad39.jpg), type is jpg
# Downloading image 82 (https://cdn10.picryl.com/photo/1971/08/02/as15-90-12324-apollo-15-apollo-15-mission-image-view-of-craters-jansen-b-ross-2b0016-1600.jpg), type is jpg
# Downloading image 83 (http://andrewplanck.com/wp-content/uploads/2017/08/Lalande-A-640x350.png), type is png
# could not load : http://andrewplanck.com/wp-content/uploads/2017/08/Lalande-A-640x350.png
# HTTP Error 412: Precondition Failed
# Downloading image 84 (https://www.cloudynights.com/uploads/monthly_02_2019/post-17157-0-66313700-1550450635.jpg), type is jpg
# could not load : https://www.cloudynights.com/uploads/monthly_02_2019/post-17157-0-66313700-1550450635.jpg
# HTTP Error 403: Forbidden
# Downloading image 85 (https://media.springernature.com/lw785/springer-static/image/chp%3A10.1007%2F978-0-387-87610-8_17/MediaObjects/978-0-387-87610-8_17_Figc_HTML.jpg), type is jpg
# Downloading image 86 (https://www.astronomyclub.xyz/moon-features/images/4872_32_69.jpg), type is jpg
# could not load : https://www.astronomyclub.xyz/moon-features/images/4872_32_69.jpg
# HTTP Error 403: Forbidden
# Downloading image 87 (https://www.moongiant.com/moonmap/images/small/topright.jpg), type is jpg
# Downloading image 88 (http://www.damianpeach.com/images/lunar0709/aristillus_2007_05_26dp.jpg), type is jpg
# Downloading image 89 (https://maas.museum/app/uploads/sites/6/2009/09/plinius-two-views_Harry-Roberts.jpg), type is jpg
# Downloading image 90 (http://tocobs.org/moon/moposi.jpg), type is jpg
# Downloading image 91 (http://www.lpi.usra.edu/resources/apollo/images/print/AS17/M/2415.jpg), type is jpg
# Downloading image 92 (http://apollo.sese.asu.edu/LIW/img/20080513_img1_tn.png), type is png
# Downloading image 93 (https://i.pinimg.com/originals/6a/fa/f3/6afaf3d873d79656c0459299b7c78d09.jpg), type is jpg
# Downloading image 94 (https://upload.wikimedia.org/wikipedia/commons/thumb/c/c0/Opelt_crater_4120_h2.jpg/320px-Opelt_crater_4120_h2.jpg), type is jpg
# Downloading image 95 (https://www.cloudynights.com/uploads/monthly_03_2018/post-211131-0-21406700-1521826072.jpg), type is jpg
# could not load : https://www.cloudynights.com/uploads/monthly_03_2018/post-211131-0-21406700-1521826072.jpg
# HTTP Error 403: Forbidden
# Downloading image 96 (https://media.springernature.com/lw785/springer-static/image/chp%3A10.1007%2F978-3-642-14805-7_6/MediaObjects/978-3-642-14805-7_6_Fig46_HTML.gif), type is gif
# Downloading image 97 (http://andrewplanck.com/wp-content/uploads/2017/11/ritter-and-sabine-craters-on-the-moon-640x350.png), type is png
# could not load : http://andrewplanck.com/wp-content/uploads/2017/11/ritter-and-sabine-craters-on-the-moon-640x350.png
# HTTP Error 412: Precondition Failed
# Downloading image 98 (http://i1215.photobucket.com/albums/cc517/lupuvictor1/Lunar%20images%202012/29042012lunapppppppppppppppppppppp_zps2be6542c.jpg), type is jpg
# Downloading image 99 (https://media.wired.com/photos/5932ccbe58b0d64bb35d3a50/master/w_900,c_limit/Apollo11-landing-site.jpg), type is jpg
# Downloading image 0 (https://upload.wikimedia.org/wikipedia/commons/thumb/e/e8/Rheita_LAC_114.jpg/220px-Rheita_LAC_114.jpg), type is jpg
# Downloading image 1 (https://upload.wikimedia.org/wikipedia/commons/thumb/4/40/Rheita_crater_4064_h2_h3.jpg/220px-Rheita_crater_4064_h2_h3.jpg), type is jpg
# Downloading image 2 (https://hwilson.zenfolio.com/img/s/v-3/p884318150-3.jpg), type is jpg
# Downloading image 3 (http://salzgeber.at/astro/moon/vallis_rheita.jpg), type is jpg
# Downloading image 4 (https://upload.wikimedia.org/wikipedia/commons/7/7e/Rheita_lunar_crater_map.jpg), type is jpg
# Downloading image 5 (https://stargazerslounge.com/applications/core/interface/imageproxy/imageproxy.php?img=http://cdn.astrobin.com/images/thumbs/8bfaedaf5d23c5e7b63402f533fb0225.1824x0_q100_watermark_watermark_opacity-10_watermark_position-4_watermark_size-M_watermark_text-Copyright%2520astroavani.jpg&key=a8393b6a551ca6e366beabdf6c54d57744578b9b59ec3ba7a82572dd5cc68ac6), type is php
# Downloading image 6 (https://live.staticflickr.com/64/30672199294_d974452961_b.jpg), type is jpg
# Downloading image 7 (https://sites.google.com/site/mickhyde/rheita-100906.jpg), type is jpg
# Downloading image 8 (http://andrewplanck.com/wp-content/uploads/2016/07/Vallis-Rheita.png), type is png
# could not load : http://andrewplanck.com/wp-content/uploads/2016/07/Vallis-Rheita.png
# HTTP Error 412: Precondition Failed
# Downloading image 9 (https://upload.wikimedia.org/wikipedia/commons/0/0e/Brenner_%2B_Metius_%2B_Rheita_-_LROC_-_WAC.JPG), type is jpg
# Downloading image 10 (http://www.chamaeleon-observatory-onjala.de/mondatlas-2-en/bilder/2016-4-8-tage-22-5prozent/vallis-rheita.png), type is png
# Downloading image 11 (https://live.staticflickr.com/7342/12321548293_8b3f6dfa7f_b.jpg), type is jpg
# Downloading image 12 (http://andrewplanck.com/wp-content/uploads/2018/06/Vallis-Rheita.png), type is png
# could not load : http://andrewplanck.com/wp-content/uploads/2018/06/Vallis-Rheita.png
# HTTP Error 412: Precondition Failed
# Downloading image 13 (http://www.madpc.co.uk/~peterl/Moon/Craters/Rheita040901_23-46-14.jpg), type is jpg
# Downloading image 14 (https://upload.wikimedia.org/wikipedia/commons/3/3a/Janssen_%28LRO%29.png), type is png
# Downloading image 15 (http://i941.photobucket.com/albums/ad252/lupuvictor/RheitaandMetius.jpg), type is jpg
# Downloading image 16 (https://the-moon.us/images/d/d9/Normal_rheitanb.jpg), type is jpg
# Downloading image 17 (https://photos.smugmug.com/Astronomy/TheSolarSystem/i-zJwBBPh/1/dd049bc2/S/Moon_120420161938-S.png), type is png
# Downloading image 18 (http://www.starfieldobservatory.com/images/xxx%202018_07_18%2017_48_45%205%20Vallis%20Rheita%20Def%20100-3cs1.jpg), type is jpg
# Downloading image 19 (https://farm6.staticflickr.com/5495/11258905025_7fa055b556_b.jpg), type is jpg
# Downloading image 20 (https://upload.wikimedia.org/wikipedia/commons/5/55/Tycho_LRO.png), type is png
# Downloading image 21 (https://farm9.static.flickr.com/8523/8477643574_c67ee5ac34_b.jpg), type is jpg
# Downloading image 22 (http://andrewplanck.com/wp-content/uploads/2016/07/LunarDay4.png), type is png
# could not load : http://andrewplanck.com/wp-content/uploads/2016/07/LunarDay4.png
# HTTP Error 412: Precondition Failed
# Downloading image 23 (http://higginsandsons.com/astro/images/Furnerius-Rheita-Valley-Mosaic-09-06-09-X14-2.jpg), type is jpg
# Downloading image 24 (https://www.cloudynights.com/uploads/gallery/category_322/gallery_18962_322_1407437811_9184.jpg), type is jpg
# could not load : https://www.cloudynights.com/uploads/gallery/category_322/gallery_18962_322_1407437811_9184.jpg
# HTTP Error 403: Forbidden
# Downloading image 25 (https://upload.wikimedia.org/wikipedia/commons/0/00/Vallis_Snellius_%2B_Vallis_Rheita_-_LRO_-_DTM.jpg), type is jpg
# Downloading image 26 (https://c8.alamy.com/comp/ANRWXJ/vallis-rheita-valley-of-the-moon-ANRWXJ.jpg), type is jpg
# Downloading image 27 (https://stargazerslounge.com/uploads/monthly_2017_11/large.oaCapture-20171106-225940_g3_ap940rs6ps5left.png.4f6d7f44d9f577efd4ec78cb94c706a7.png), type is png
# Downloading image 28 (https://images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com/f/61ea2b90-ea57-460d-ab1a-e4020900373a/da28tsm-ac1c6263-db8c-4a55-84ea-af0aa3eb3ee7.jpg/v1/fill/w_1009,h_792,q_70,strp/janssen_crater_and_rheita_valley_newton_200mm_by_arayashikinoshaka_da28tsm-pre.jpg?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..0JrH6DEx-qSw2it_e7XckclP-JMkoryl_p6g16fNGrc), type is jpg
# Downloading image 29 (https://upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Mallet_crater_4064_h2.jpg/240px-Mallet_crater_4064_h2.jpg), type is jpg
# Downloading image 30 (https://www.lcas-astronomy.org/articles/images/moonvaly.jpg), type is jpg
# Downloading image 31 (http://www.salzgeber.at/wordpress/wp-content/uploads/2018/04/Moon_2018_04_20_212443_AS_P20_lapl4_ap1055_wav3.jpg), type is jpg
# Downloading image 32 (http://mw1.google.com/mw-planetary/lunar/lunarmaps_v1/clem_bw/7/82/47.jpg), type is jpg
# Downloading image 33 (http://www.chamaeleon-observatory-onjala.de/mondatlas-2-en/bilder/17prozent/006-0029-furnerius-rheita.png), type is png
# Downloading image 34 (https://upload.wikimedia.org/wikipedia/commons/thumb/7/71/Metius_crater_4071_h2.jpg/220px-Metius_crater_4071_h2.jpg), type is jpg

# %% [markdown]
# ## 画像を整形する

# %%
#【Python】画像の解像度の変更。リサイズ（拡大・縮小） 
# https://www.tech-tech.xyz/python-img-resize.html
# Python, Pillowで画像の一部をトリミング（切り出し/切り抜き）
# https://note.nkmk.me/python-pillow-image-crop-trimming/
import glob
import os
from PIL import Image
import pathlib

rect_width = 250


def resize_downloaded_images():

  for crater_name in crater_name_list:
      
      in_dir = drive_root_dir + "/resources/"+crater_name
      file_name_list = pathlib.Path(in_dir).glob('*.jpg')
      for file in file_name_list:
          print(file)
          
          img = Image.open(file)
          
          img_width, img_height = img.size
          if img_width > img_height:
            resize_width = rect_width / img_height * img_width
            img_resize = img.resize((int(resize_width), rect_width))
            im_crop = img_resize.crop((0, 0, rect_width, rect_width))
            im_crop.save(drive_root_dir + "/resources/resized/" + crater_name + "/" + file_name)
          else:
            resize_height = rect_width / img_width * img_height
            img_resize = img.resize((rect_width, int(resize_height)))
            im_crop = img_resize.crop((0, 0, rect_width, rect_width))
            im_crop.save(drive_root_dir + "/resources/resized/" + crater_name + "/" + file_name)

# %%
resize_downloaded_images()

# %% [markdown]
# ## 画像をテスト用と学習用に分ける

# %%
# KerasのCNNで、顔認識AIを作って見た〜スクレイピングからモデルまで〜
# ( @yottyann1221 2019年03月07日に更新) より
# https://qiita.com/yottyann1221/items/a08300b572206075ee9f#%E3%81%AF%E3%81%98%E3%82%81%E3%81%AB

import shutil
import random
import glob
import os

crater_name_list = [
      "Albategnius", "Aristarchus", "Aristotle", "Bailly", "Clavius",
      "Copernicus", "Humboldt", "Janssen", "Langrenus",
      "Longomontanus", "Maginus", "Metius", "Moretus", "Petavius", "Picard",
      "Piccolomini", "Pitatus", "Plinius", "Rheita", "Russell", "Schickard",
      "Seleucus", "Stadius", "Stöfler", "Thebit", "Theophilus", "Tycho",
      "Vendelinus", "Wargentin"
    ]

def divide_data_test_train():
  for crater_name in crater_name_list:
      in_dir = drive_root_dir + "/resources/resized/"+crater_name+"/*"
      in_jpg=glob.glob(in_dir)
      img_file_name_list=os.listdir(drive_root_dir + "/resources/resized/"+crater_name+"/")
      random.shuffle(in_jpg)
      if os.path.exists(drive_root_dir + '/resources/resized/test/' + crater_name):
          shutil.rmtree(drive_root_dir + '/resources/resized/test/' + crater_name)
      os.makedirs(drive_root_dir + '/resources/resized/test/' + crater_name)
      for t in range(len(in_jpg)//5):
          shutil.move(str(in_jpg[t]), drive_root_dir + "/resources/resized/test/"+crater_name)

# %%
divide_data_test_train()

# %% [markdown]
# ## 画像をラベルづけする

# %%
# KerasのCNNで、顔認識AIを作って見た〜スクレイピングからモデルまで〜
# ( @yottyann1221 2019年03月07日に更新) より
# https://qiita.com/yottyann1221/items/a08300b572206075ee9f#%E3%81%AF%E3%81%98%E3%82%81%E3%81%AB

import cv2
from keras.utils.np_utils import to_categorical
import numpy as np

# 教師データのラベル付け
X_train = [] 
Y_train = [] 
for crater_name in crater_name_list:
    img_file_name_list=os.listdir(drive_root_dir + "/resources/resized/"+crater_name)
    print("{}:トレーニング用の写真の数は{}枚です。".format(crater_name,len(img_file_name_list)))

    for file_name in img_file_name_list:
        n=os.path.join(drive_root_dir + "/resources/resized/"+crater_name+"/",file_name)  
        img = cv2.imread(n)
        if img is None:
            print('image' + str(j) + ':NoImage')
            continue    
        else:
            r,g,b = cv2.split(img)
            img = cv2.merge([r,g,b])
            X_train.append(img)
            Y_train.append(i)

print("")

# テストデータのラベル付け
X_test = [] # 画像データ読み込み
Y_test = [] # ラベル（名前）
for crater_name in crater_name_list:
    img_file_name_list=os.listdir(drive_root_dir + "/resources/resized/test/"+crater_name)
    print("{}:テスト用の写真の数は{}枚です。".format(crater_name,len(img_file_name_list)))
    for file_name in img_file_name_list:
        n=os.path.join(drive_root_dir + "/resources/resized/test/"+crater_name+"/",file_name)
        img = cv2.imread(n)
        if img is None:
            print('image' + str(j) + ':NoImage')
            continue    
        else:
            r,g,b = cv2.split(img)
            img = cv2.merge([r,g,b])
            X_test.append(img)
            Y_test.append(i)

X_train=np.array(X_train)
X_test=np.array(X_test)
y_train = to_categorical(Y_train)
y_test = to_categorical(Y_test)

# %% [markdown]
# # 2. モデルをつくる

# %%
# KerasのCNNで、顔認識AIを作って見た〜スクレイピングからモデルまで〜
# ( @yottyann1221 2019年03月07日に更新) より
# https://qiita.com/yottyann1221/items/a08300b572206075ee9f#%E3%81%AF%E3%81%98%E3%82%81%E3%81%AB

from keras.layers import Activation, Conv2D, Dense, Flatten, MaxPooling2D
from keras.models import Sequential

input_shape=(250,250,3)

# モデルの定義
model = Sequential()
model.add(Conv2D(input_shape=input_shape, filters=32,kernel_size=(3, 3), 
                 strides=(1, 1), padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(filters=32, kernel_size=(3, 3), 
                 strides=(1, 1), padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(filters=32, kernel_size=(3, 3), 
                 strides=(1, 1), padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(256))
model.add(Activation("sigmoid"))
model.add(Dense(128))
model.add(Activation('sigmoid'))
# 分類したい人数を入れる
model.add(Dense(len(crater_name_list)))
model.add(Activation('softmax'))

# コンパイル
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# 学習
history = model.fit(X_train, y_train, batch_size=70, 
                    epochs=50, verbose=1, validation_data=(X_test, y_test))
